# %% [markdown]
# # Search: Solving a Maze Using a Goal-based Agent
#
# Student Name: Thomas Jones
#
# I have used the following AI tools: [list tools]
#
# I understand that my submission needs to be my own work: TJ

# %% [markdown]
# ## Learning Outcomes
#
# * Formulate search problems using key components like initial state, actions, and goal state in a deterministic, fully observable environment.
# * Implement and compare search algorithms including BFS, DFS, GBFS, A*, and IDS for planning paths through mazes.
# * Analyze algorithm performance by measuring path cost, node expansions, depth, and memory usage across various maze types.
# * Use visualization tools to represent maze paths and support debugging and analysis.

# %% [markdown]
# ## Instructions
#
# Total Points: Undergrads 100 + 5 bonus / Graduate students 110
#
# Complete this notebook. Use the provided notebook cells and insert additional code and markdown cells as needed. Submit the notebook file and the completely rendered notebook with all outputs as a HTML file.
#
#
# ## Introduction
#
# In this exercise, we will implement the planning function for a type of goal-based agent called a __planning agent__. The planning function uses a map it is given to plan a path through the maze from the starting location $S$ to the goal location $G$. We will only focus on the planning function, so you do not need to implement an environment, just use the map to search for a path to solve the maze.
#
# Once the plan is made, the agent in a deterministic environment (i.e., the transition function is deterministic with the outcome of each state/action pair fixed and no randomness) can just follow the plan step-by-step and does not need to care about the percepts.
# This is also called an **[open-loop system](https://en.wikipedia.org/wiki/Open-loop_controller).**
# The execution phase is trivial and can be executed using a model-based reflex agent
# that ignores all percepts and just follows the plan. I will show you a short example, but you do not implement it in this exercise.
#
# Given that the agent has a complete and correct map, the environment is **fully observable, discrete, deterministic, and known.**
# Remember:
#
# * **Fully observable** means that the agent can see its state and what the available actions are. That means the **percepts contain the complete current state.**
# Here, during planning, the agent always sees its x and y coordinates on the map and
# also seeks when it has reached the goal state.
# * **Discrete** means that we have a **finite set of states.** The maze has a finite set
# of squares the agent can be in.
# * **Deterministic** means that the **transition function contains no randomness.** An action in a state will always produce the same result. Going south from the start state always will lead to the same square.
# * **Know** means that the agent **knows the complete transition function.** The
# agent has the map and therefore knows how its position changes when it walks in a direction.
#
# Tree search algorithm implementations that you find online typically come from data structures courses and have a different aim than AI tree search. These algorithms assume that you already have a tree in memory. We are interested in dynamically creating a search tree with the aim of finding a good/the best path from the root note to the goal state. Follow the pseudo code presented in the text book (and replicated in the slides) closely. Ideally, we would like to search only a small part of the maze, i.e., create a search tree with as few nodes as possible.
#
# Several mazes for this exercise are stored as text files. We need to make sure that they are locally available.

# %%
import urllib.request
import os

def download(file, base_url):
    if not os.path.exists(file):
        urllib.request.urlretrieve(base_url + file, file)

base_url = "https://raw.githubusercontent.com/mhahsler/Introduction_to_Artificial_Intelligence/refs/heads/master/Search/"
download("maze_helper.py", base_url)

mazes = ["small_maze.txt", "medium_maze.txt", "large_maze.txt", "L_maze.txt", "empty_maze.txt", "empty_maze_2.txt", "loops_maze.txt", "open_maze.txt", ]
for maze in mazes:
    download(maze, base_url)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Here is the small example maze:

# %%
with open("small_maze.txt", "r") as f:
    maze_str = f.read()
print(maze_str)
# Out:
# XXXXXXXXXXXXXXXXXXXXXX
# X XX        X X      X
# X    XXXXXX X XXXXXX X
# XXXXXX     S  X      X
# X    X XXXXXX XX XXXXX
# X XXXX X         X   X
# X        XXX XXX   X X
# XXXXXXXXXX    XXXXXX X
# XG         XX        X
# XXXXXXXXXXXXXXXXXXXXXX

# %% [markdown]
# **Note:** If you get an error here that the file cannot be found, then you need to download it. See [HOWTO Work on Assignments.](https://github.com/mhahsler/CS7320-AI/blob/master/HOWTOs/working_on_assignments.md)

# %% [markdown]
# ## Parsing and pretty printing the maze
#
# The maze can also be displayed in color using code in the module [maze_helper.py](maze_helper.py). The code parses the string representing the maze and converts it into a `numpy` 2d array which you can use in your implementation. Position are represented as a 2-tuple of the form `(row, col)`.

# %%
import maze_helper as mh

maze = mh.parse_maze(maze_str)

# look at a position in the maze by subsetting the 2d array
print("Position(0,0):", maze[0, 0])

# there is also a helper function called `look(maze, pos)` available
# which uses a 2-tuple for the position.
print("Position(8,1):", mh.look(maze, (8, 1)))
# Out:
# Position(0,0): X
# Position(8,1): G

# %% [markdown]
# A helper function to visualize the maze is also available.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# use higher resolution images in notebooks

mh.show_maze(maze)

# %% [markdown]
# Find the `(x,y)` position of the start and the goal using the helper function `find_pos()`

# %%
print("Start location:", mh.find_pos(maze, what = "S"))
print("Goal location:", mh.find_pos(maze, what = "G"))
# Out:
# Start location: (np.int64(3), np.int64(11))
# Goal location: (np.int64(8), np.int64(1))

# %% [markdown]
# Helper function documentation.

# %%
help(mh)
# Out:
# Help on module maze_helper:
#
# NAME
#     maze_helper
#
# DESCRIPTION
#     Code for the Maze Assignment by Michael Hahsler
#     Usage:
#         import maze_helper as mh
#         mh.show_some_mazes()
#
# FUNCTIONS
#     animate_maze(result, repeat=False)
#         (Experimental) Build an animation from a list of mazes. This needs ffmpeg to be installed.
#
#         Parameters:
#             result: a list with the elements path, reached, actions and maze_anim with a list of maze arrays that contain what you want to visualize.
#             repeat: if True, the animation will repeat.
#
#     find_pos(maze, what='S')
#         Find start/goal in a maze and returns the first one.
#         Caution: there is no error checking!
#
#         Parameters:
#             maze: a array with characters produced by parse_maze()
#             what: the letter to be found ('S' for start and 'G' for goal)
#
#         Returns:
#             a tupple (x, y) for the found position.
#
# ...

# %% [markdown]
# You will need to make a local copy of the module file [maze_helper.py](maze_helper.py) in the same folder where your notebook is.

# %% [markdown]
# ## An Example for a Planning Agent
#
# I will show you here how to implement a simple agent that uses a random plan. It will not solve the maze, but show you how the mechanics work.
#
# First, we define a generic planning agent that fist plans, and then executes the plan step-by-step.

# %%
class Planning_Agent:
    def __init__(self, maze, start, goal, planning_function):
        self.maze = maze
        self.start = start
        self.goal = goal
        self.planning_function = planning_function
        self.plan = None
        self.progress = None

    def act(self):
        # plan if no plan exists
        if self.plan is None:
            print("Planning...")
            self.plan = self.planning_function(self.maze, self.start, self.goal)
            self.progress = 0

        # check if plan is completed
        if self.progress >= len(self.plan):
            raise Exception("Completed Plan. No more planned actions")

        # follow the plan
        action = self.plan[self.progress]
        print(f"Following plan... step {self.progress}: {action}")

        self.progress += 1
        return action

# %% [markdown]
# Next, we define the planning function. This function is what you will implement in this assignment.

# %%
import numpy as np

def plan_random(maze, start, goal):
    """Create a random plan with 10 steps"""
    plan = np.random.choice(["N", "E", "S", "W"], size=10, replace=True).tolist()
    return plan

plan_random(maze, (1,1), (8,8))
# Out:
# ['E', 'W', 'E', 'N', 'N', 'E', 'W', 'S', 'W', 'N']

# %% [markdown]
# This planning function is not great and will not produce a plan that solves the maze. Your planning functions will do better.
#
# Finally, we can create the planning agent, give it the planning function and implement a simple environment that asks it 11 times for an action.

# %%
my_agent = Planning_Agent(maze, mh.find_pos(maze, what = "S"), mh.find_pos(maze, what = "G"), plan_random)

def environment(agent_function, steps):
    for _ in range(steps):
        try:
            agent_function()
        except Exception as e:
            print(f"Agent exception: {e}")

environment(my_agent.act, steps=11)
# Out:
# Planning...
# Following plan... step 0: E
# Following plan... step 1: S
# Following plan... step 2: S
# Following plan... step 3: S
# Following plan... step 4: N
# Following plan... step 5: W
# Following plan... step 6: N
# Following plan... step 7: N
# Following plan... step 8: E
# Following plan... step 9: N
# Agent exception: Completed Plan. No more planned actions

# %% [markdown]
# Note: The agent and environment implementation above is just an illustration. You will only implement and experiment with different versions of the planning function.

# %% [markdown]
# ## Tree structure
#
# To use tree search, you will need to implement a tree data structure in Python.
# Here is an implementation of the basic node structure for the search algorithms (see Fig 3.7 on page 73). I have added a method that extracts the path from the root node to the current node. It can be used to get the path when the search is completed.

# %%
class Node:
    def __init__(self, pos, parent, action, cost):
        self.pos = tuple(pos)    # the state; positions are (row,col)
        self.parent = parent     # reference to parent node. None means root node.
        self.action = action     # action used in the transition function (root node has None)
        self.cost = cost         # for uniform cost this is the depth. It is also g(n) for A* search

    def __str__(self):
        return f"Node - pos = {self.pos}; action = {self.action}; cost = {self.cost}"

    def get_path_from_root(self):
        """returns nodes on the path from the root to the current node."""
        node = self
        path = [node]

        while not node.parent is None:
            node = node.parent
            path.append(node)

        path.reverse()

        return(path)

# %% [markdown]
# If needed, then you can add more fields to the class like the heuristic value $h(n)$ or $f(n)$.
#
# Examples for how to create and use a tree and information on memory management can be found [here](../HOWTOs/trees.ipynb).

# %% [markdown]
# # Tasks
#
# The goal is to:
#
# 1. Implement the following search algorithms for solving different mazes:
#
#     - Breadth-first search (BFS)
#     - Depth-first search (DFS)
#     - Greedy best-first search (GBFS)
#     - A* search
#
# 2. Run each of the above algorithms on the
#     - [small maze](small_maze.txt),
#     - [medium maze](medium_maze.txt),
#     - [large maze](large_maze.txt),
#     - [open maze](open_maze.txt),
#     - [L maze](L_maze.txt),
#     - [loops maze](loops_maze.txt),
#     - [empty maze](empty_maze.txt), and
#     - [empty maze (rotated)](empty_maze_2.txt).
#
# 3. For each problem instance and each search algorithm, report the following in a table:
#
#     - The solution and its path cost
#     - Total number of nodes expanded
#     - Maximum tree depth
#     - Maximum size of the frontier
#
# 4. Display each solution by marking every maze square (or state) visited and the squares on the final path.
#
# ## General [10 Points]
#
# 1. Make sure that you use the latest version of this notebook.
# 2. Your implementation can use libraries like math, numpy, scipy, but not libraries that implement intelligent agents or complete search algorithms. Try to keep the code simple! In this course, we want to learn about the algorithms and we often do not need to use object-oriented design.
# 3. You notebook needs to be formatted professionally.
#     - Add additional markdown blocks for your description, comments in the code, add tables and use mathplotlib to produce charts where appropriate
#     - Do not show debugging output or include an excessive amount of output.
#     - Check that your submitted file is readable and contains all figures.
# 4. Document your code. Use comments in the code and add a discussion of how your implementation works and your design choices.

# %% [markdown]
# ## Task 1: Defining the search problem and determining the problem size [10 Points]
#
# Define the components of the search problem:
#
# * Initial state
# * Actions
# * Transition model
# * Goal state
# * Path cost
#
# Use verbal descriptions, variables and equations as appropriate.
#
# *Note:* You can swich the next block from code to Markdown and use formating.

# %% [markdown]
# Initial state: The starting position S of the agent in the maze, represented as a coordinate tuple.
#
# Actions: From any non-wall cell, the agent can move in four directions: North, South, East, West. An action is valid only if the target cell is within the maze boundary and is not a wall.
#
# Transition model: T(s, a) = s' where s' = (row+-1, col) or (row, col+-1) depending on action a. The same action from the same state always produces the same result.
#
# Goal state: the cell containing G in the maze.
#
# Path cost: The number of steps taken from the initial state to the current state. Each action has a cost of 1, so path cost = number of actions taken.

# %% [markdown]
# Give some estimates for the problem size:
#
# * $n$: state space size
# * $d$: depth of the optimal solution
# * $m$: maximum depth of tree
# * $b$: maximum branching factor
#
# Describe how you would determin these values for a given maze.

# %% [markdown]
# n (state space size): The number of non-wall cells in the maze. For a maze of dimensions R x C, n <= R x C. For the small maze, n <= 220, but typically far fewer after excluding walls.
#
# d (deoth of optimal solution): The length of the shortest path from S to G. Found by BFS, for the small maze d = 19.
#
# m (maximum depth of tree): Without a cycle check, this is unbounded with cycle checking m <= n-1.
#
# b (maximum branching factor): At most 4 but walls and already visited cells reduce this.

# %% [markdown]
# ## Task 2: Uninformed search: Breadth-first and depth-first [40 Points]
#
# Implement these search strategies. Follow the pseudocode in the textbook/slides. You can use the tree structure shown above to extract the final path from your solution.
#
# Read the following **important notes** carefully:
# * You can find maze solving implementations online that use the map to store information. While this is an effective idea for this two-dimensional navigation problem, it typically cannot be used for other search problems. Therefore, follow the textbook and **do not store information in the map.** Only store information in the tree created during search, and use the `reached` and `frontier` data structures where appropriate.
# * DSF behavior can be implemented using the BFS tree search algorithm and simply changing the order in which the frontier is expanded (this is equivalent to best-first search with path length as the criterion to expand the next node). However, this would be a big mistake since it combines the bad space complexity of BFS with the bad time complexity of DFS! **To take advantage of the significantly smaller memory footprint of DFS, you need to implement DFS in a different way without a `reached` data structure (often also called `visited` or `explored`) and by releasing the memory for nodes that are not needed anymore.**
# * Since the proper implementation of DFS does not use a `reached` data structure, redundant path checking abilities are limited to cycle checking.
# You need to implement **cycle checking since DSF is incomplete (produces an infinite loop) if cycles cannot be prevented.** You will see in your experiments that cycle checking in open spaces is challenging.

# %%
from collections import deque

#Global directions for consistency
directions = {
    "N": (-1, 0),
    "E": (0, 1),
    "S": (1, 0),
    "W": (0, -1)
}

def is_valid(maze, pos):
    """Check bounds and not a wall"""
    r, c = pos
    return (0 <= r < maze.shape[0] and
            0 <= c < maze.shape[1] and
            maze[r, c] != 'X')

def plan_bfs(maze, start, goal):
  """Breadth-First Search using a FIFO queue.
    Uses a 'reached' set to avoid revisiting states.
    """
    #tuples so they can be used in sets
  start, goal = tuple(start), tuple(goal)
  if start == goal: return [], 0, 0, 0, 1

  # Initialize frontier and tracking variables
  frontier = deque([Node(start, None, None, 0)])
  reached = {start} # Avoid revisiting any state
  nodes_expanded = 0
  max_depth = 0
  max_frontier = 1
  max_memory = 1 #frontier + reached

  while frontier:
    current = frontier.popleft() #dequeue from front
    nodes_expanded += 1
    max_depth = max(max_depth, current.cost)

    if current.pos == goal:
      path = current.get_path_from_root()
      plan = [node.action for node in path[1:]] #Skip starting node
      return plan, current.cost, nodes_expanded, max_depth, max_frontier, max_memory

    #Generate child nodes in all 4 directions
    for action, (dr, dc) in directions.items():
      child_pos = (current.pos[0]+dr, current.pos[1]+dc)
      if is_valid(maze, child_pos) and child_pos not in reached:
        child = Node(child_pos, current, action, current.cost+1)
        frontier.append(child) #Enqueue at back
        reached.add(child_pos)
        max_frontier = max(max_frontier, len(frontier))
        max_memory = max(max_memory, len(frontier) + len(reached))
  return None, None, nodes_expanded, max_depth, max_frontier, max_memory

def plan_dfs(maze, start, goal, max_expansions=50000):
  """
  Depth-First Search using a LIFO stack.
  No full 'reached' set — only cycle checking on the current path.
  This preserves DFS's memory advantage over BFS.
  """
  start, goal = tuple(start), tuple(goal)
  if start == goal: return [], 0, 0, 0, 1

  # Use regular list as stack
  frontier = [Node(start, None, None, 0)] #stack
  nodes_expanded = 0
  max_depth = 0
  max_frontier = 1
  max_memory = 1

  while frontier:
    current = frontier.pop() # pop from end
    nodes_expanded += 1
    max_depth = max(max_depth, current.cost)

    if nodes_expanded > max_expansions:
      return None, None, nodes_expanded, max_depth, max_frontier, max_memory

    if current.pos == goal:
      path = current.get_path_from_root()
      plan = [node.action for node in path[1:]]
      return plan, current.cost, nodes_expanded, max_depth, max_frontier, max_memory

    # Get all positions in current path to prevent immediate cycles
    path_nodes = current.get_path_from_root()
    path_positions = {node.pos for node in current.get_path_from_root()}
    current_path_len = len(path_nodes) # needed to calculate max_memory for DFS

    # Try expanding in each direction
    for action, (dr, dc) in directions.items():
      child_pos = (current.pos[0]+dr, current.pos[1]+dc)
      if is_valid(maze, child_pos) and child_pos not in path_positions:
        child = Node(child_pos, current, action, current.cost+1)
        frontier.append(child) #Push onto stack
        max_frontier = max(max_frontier, len(frontier))
        max_memory = max(max_memory, len(frontier) + current_path_len) #DFS has no reached

  return None, None, nodes_expanded, max_depth, max_frontier, max_memory

# %%
maze = mh.parse_maze(open("small_maze.txt").read())
start = mh.find_pos(maze, "S")
goal  = mh.find_pos(maze, "G")

plan, cost, expanded, depth, max_frontier, max_memory = plan_bfs(maze, start, goal)
print("BFS plan:", plan)
print("Path cost:", cost, "Nodes expanded:", expanded,"Max depth:", depth, "Max frontier:", max_frontier)
# Out:
# BFS plan: ['E', 'E', 'S', 'S', 'W', 'S', 'S', 'W', 'W', 'S', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W']
# Path cost: 19 Nodes expanded: 93 Max depth: 19 Max frontier: 9

# %% [markdown]
# How does BFS and DFS (without a reached data structure) deal with loops (cycles)?

# %% [markdown]
# BFS handles loops using a 'reached' set that records every state added to the frontier. It checks if the child's position is already in 'reached' before adding it. If it is, it is skiped entirely.
#
# DFS handles loops using cycle checking on the current path. For each candidate child, we walk the current path back to the root and check for a repeat. This prevents infinite loops on the current branch while allowing the same state to be expanded.

# %% [markdown]
# Are your implementations complete and optimal? Explain why. What is the time and space complexity of each of **your** implementations? Especially discuss the difference in space complexity between BFS and DFS.

# %% [markdown]
# My implementations are complete for both BFS and DFS but optimal for only BFS as it is a uniform cost. The time complexity for BFS is O(b^d) and for DFS it is O(b^m). The space complexity for BFS is O(b^d) and for DFS it is O(b*m).
#
# The difference in space complexities is because BFS stores all frontier nodes while DFS only stores the current branch plus siblings.

# %% [markdown]
# ## Task 3: Informed search: Implement greedy best-first search and A* search  [20 Points]
#
# You can use the map to estimate the distance from your current position to the goal using the Manhattan distance (see https://en.wikipedia.org/wiki/Taxicab_geometry) as a heuristic function. Both algorithms are based on Best-First search which requires only a small change from the BFS algorithm you have already implemented (see textbook/slides).

# %%
def manhattan_distance(pos, goal):
    return abs(pos[0] - goal[0]) + abs(pos[1] - goal[1])

def pop_min(frontier):
  """Remove and return the node with smallest priority"""
  idx = np.argmin([item[0]for item in frontier]) # priority is first element
  return frontier.pop(idx)

def plan_gbfs(maze, start, goal):
  """Greedy Best-First Search using a priority queue."""
  start, goal = tuple(start), tuple(goal)
  if start == goal: return [], 0, 0, 0, 1

  # Frontier stores tuples: (heuristic score, Node)
  frontier = [(manhattan_distance(start, goal), Node(start, None, None, 0))]
  reached = {start} # visited set
  nodes_expanded = 0
  max_depth = 0
  max_frontier = 1
  max_memory = 1

  while frontier:
    _, current = pop_min(frontier) # Always expand the most promising node (lowest h)
    nodes_expanded += 1
    max_depth = max(max_depth, current.cost)

    if current.pos == goal:
      path = current.get_path_from_root()
      plan = [n.action for n in path[1:]]
      return plan, current.cost, nodes_expanded, max_depth, max_frontier, max_memory

    # Try all four directions
    for action, (dr, dc) in directions.items():
      child_pos = (current.pos[0]+dr, current.pos[1]+dc)
      if is_valid(maze, child_pos) and child_pos not in reached:
        reached.add(child_pos)
        child = Node(child_pos, current, action, current.cost+1)
        h = manhattan_distance(child_pos, goal) # heuristic priority
        frontier.append((h, child))
        max_frontier = max(max_frontier, len(frontier))
        max_memory = max(max_memory, len(frontier) + len(reached))
  return None, None, nodes_expanded, max_depth, max_frontier, max_memory

def plan_astar(maze, start, goal):
  """A* Search using a priority queue."""
  start, goal = tuple(start), tuple(goal)
  if start == goal: return [], 0, 0, 0, 1

  # Frontier stores tuples: (f score, Node)
  frontier = [(manhattan_distance(start, goal), Node(start, None, None, 0))]
  reached = {start: 0} # reached tracks the best known cost g to reach each position
  nodes_expanded = 0
  max_depth = 0
  max_frontier = 1
  max_memory = 1

  while frontier:
    _, current = pop_min(frontier) #Expand node with lowest f = g + h
    nodes_expanded += 1
    max_depth = max(max_depth, current.cost)

    if current.pos == goal:
      path = current.get_path_from_root()
      plan = [n.action for n in path[1:]]
      return plan, current.cost, nodes_expanded, max_depth, max_frontier, max_memory

    # Generate children
    for action, (dr, dc) in directions.items():
      child_pos = (current.pos[0] + dr, current.pos[1]+ dc)
      if not is_valid(maze, child_pos):
        continue
      new_g = current.cost + 1 # Cost to reach child
      # If we found a better (or first) path to this position
      if child_pos not in reached or new_g < reached[child_pos]:
        reached[child_pos] = new_g
        child = Node(child_pos, current, action, new_g)
        h = manhattan_distance(child_pos, goal)
        f = new_g + h # priority
        frontier.append((f, child))
        max_frontier = max(max_frontier, len(frontier))
        max_memory = max(max_memory, len(frontier) + len(reached))

  return None, None, nodes_expanded, max_depth, max_frontier, max_memory

# %% [markdown]
# Are your implementations complete and optimal? What is the time and space complexity?

# %% [markdown]
# The Greedy Best-First algorithm is complete but not optimal as it can take detours. The time complexity is O((R x C)^2) and space complexity is O(R x C). The A* algorithm is complete and optimal because manhattan distance is consistent here. The Time complexity is O((R x C)^2) and the space complexity is O(R x C).

# %% [markdown]
# ## Task 4: Comparison and discussion [20 Points]
#
# Run experiments to compare the implemented algorithms.
#
# How to deal with issues:
#
# * Your implementation returns unexpected results: Try to debug and fix the code. Visualizing the maze, the current path and the frontier after every step is very helpful. If the code still does not work, then mark the result with an asterisk (*) and describe the issue below the table.
#
# * Your implementation cannot consistently solve a specific maze and ends up in an infinite loop:
#     Debug (likely your frontier and cycle checking for DFS are the issue). If it is a shortcoming of the algorithm/implementation, then put "N/A*" in the results table and describe why this is happening.

# %%
import pandas as pd
import time

MAX_EXPANSIONS = 80000   # stop early to prevent long runtimes

maze_files = [
    "small_maze.txt", "medium_maze.txt", "large_maze.txt", "L_maze.txt",
    "empty_maze.txt", "empty_maze_2.txt", "loops_maze.txt", "open_maze.txt"
]

algorithms = {
    "BFS": plan_bfs,
    "DFS": plan_dfs,
    "GBFS": plan_gbfs,
    "A*": plan_astar
}

results = []

for file in maze_files:
  with open(file, "r") as f:
    maze = mh.parse_maze(f.read())

  start = mh.find_pos(maze, "S")
  goal = mh.find_pos(maze, "G")
  maze_name = file.replace(".txt", "").replace("_", " ").title()


  for alg_name, alg_func in algorithms.items():
    start_time = time.time()
    if alg_name == "DFS":
      plan, cost, expanded, depth, max_frontier, max_memory = alg_func(maze, start, goal, max_expansions=MAX_EXPANSIONS)
    else:
      plan, cost, expanded, depth, max_frontier, max_memory = alg_func(maze, start, goal)
    runtime = time.time() - start_time

    path_cost = int(cost) if cost is not None else "N/A"
    expanded = expanded if expanded is not None else "N/A"
    depth = depth if depth is not None else "N/A"

    status = "Limited" if expanded == MAX_EXPANSIONS else "Completed"


    results.append({
        "maze": maze_name,
        "algorithm": alg_name,
        "path cost": path_cost,
        "# of nodes expanded": expanded,
        "max tree depth": depth,
        "max # of nodes in memory": max_memory,
        "max frontier size": max_frontier,
    })


df = pd.DataFrame(results)
df
# Out:
#             maze algorithm path cost  # of nodes expanded  max tree depth  \
# 0     Small Maze       BFS        19                   93              19
# 1     Small Maze       DFS        29                   40              29
# 2     Small Maze      GBFS        29                   40              29
# 3     Small Maze        A*        19                   54              19
# 4    Medium Maze       BFS        68                  270              68
# 5    Medium Maze       DFS       152                  154             152
# 6    Medium Maze      GBFS        74                   79              74
# 7    Medium Maze        A*        68                  223              68
# 8     Large Maze       BFS       210                  622             210
# 9     Large Maze       DFS       210                  338             214
# 10    Large Maze      GBFS       210                  467             210
# 11    Large Maze        A*       210                  550             210
# ...

# %% [markdown]
# Present the results as using charts (see [Python Code Examples/charts and tables](../HOWTOs/charts_and_tables.ipynb)).

# %%
import matplotlib.pyplot as plt

#Handle N/A values from DFS path cost
df_plot = df.copy()
df_plot['path cost'] = pd.to_numeric(df_plot['path cost'], errors='coerce')

fig, axes = plt.subplots(2, 2, figsize=(15, 10))

#Path Cost bar chart
df_plot.pivot(index="maze", columns="algorithm", values="path cost").plot(kind="bar", ax=axes[0,0], width=1)
axes[0,0].set_title('Path Cost')
axes[0,0].set_ylabel('Steps')
axes[0,0].tick_params(axis='x', rotation=45)

# num of nodes expanded bar chart
df.pivot(index="maze", columns="algorithm", values="# of nodes expanded").plot(kind="bar", ax=axes[0,1], width=1, logy=True)
axes[0,1].set_title('# of nodes expanded')
axes[0,1].set_ylabel('Nodes')
axes[0,1].tick_params(axis='x', rotation=45)

#Max tree depth line chart
df_pivot = df.pivot(index="maze", columns="algorithm", values="max tree depth")
for alg in df_pivot.columns:
  axes[1,0].plot(df_pivot.index, df_pivot[alg], label=alg)
axes[1,0].set_title("Max tree depth")
axes[1,0].set_ylabel("Depth")
axes[1,0].tick_params(axis='x', rotation=45)
axes[1,0].grid(True, alpha=0.3)
axes[1,0].legend(title="Algorithm")

#Grouped bar chart to compare max memory to frontier size
x = np.arange(len(df['maze'].unique()))
width = 0.2

for i, alg in enumerate(df['algorithm'].unique()):
    mem = df[df['algorithm'] == alg]['max # of nodes in memory'].values
    front = df[df['algorithm'] == alg]['max frontier size'].values
    axes[1,1].bar(x + i*width, mem, width, label=f'{alg} Memory', alpha=0.9)
    axes[1,1].bar(x + i*width + width/2, front, width*0.6, label=f'{alg} Frontier', alpha=0.6)

axes[1,1].set_title('Max Nodes in Memory vs Max Frontier Size')
axes[1,1].set_ylabel('Number of Nodes')
axes[1,1].set_xticks(x + 1.5*width)
axes[1,1].set_xticklabels(df['maze'].unique(), rotation=45)
axes[1,1].legend(bbox_to_anchor=(1.05, 1))

plt.tight_layout()
plt.show()

# %% [markdown]
# Discuss the most important lessons you have learned from implementing the different search strategies.

# %% [markdown]
# The first important lessons I have learned from implementing the different search strategies would be that optimality requires a form of systematic exploration. BFS does this through level-by-level exapansion and A* does so by combining path cost with a consistent heuristic, Manhattan distance.
#
# Secondly, I learned that memory and frontier size distinction matters. Tracking both revealed important differences like how BFS, GBFS, and A* store many more nodes in memory than in frontier because of the reached set used for graph search. DFS only needs to store the frontier plus the current path which results in lower memory usage.
#
# Lastly, I learned when to use each search strategy. BFS is best for when optimality is required and memory is not a concern. A* is best overall when a good heuristic is available. GBFS is best for when speed matters more than optimality as it trades optimality for speed. DFS is best when memory is limited and suboptimal solutions are still acceptable.

# %% [markdown]
# ## Advanced task: IDS and Multiple goals
#
# * __Graduate students__ need to complete this task [10 points]
# * __Undergraduate students__ can attempt this as a bonus task [max +5 bonus points].
#
# ### IDS
# Implement IDS (iterative deepening search) using your DFS implementation. Test IDS on the mazes above. You may run into some issues with mazes with open spaces. If you cannot resolve the issues, then report and discuss what causes the problems.

# %%
# Your code/answer goes here

# %% [markdown]
# ### Multiple Goals
# Create a few mazes with multiple goals by adding one or two more goals to the medium size maze. The agent is done when it finds one of the goals.
# Solve the maze with your implementations for DFS, BFS, and IDS. Run experiments to show which implementations find the optimal solution and which do not. Discuss why that is the case.

# %%
# Your code/answer goes here

# %% [markdown]
# ## More Advanced Problems to Think About (not for credit)
#
# If the assignment was to easy for yuo then you can think about the following problems. These problems are challenging and not part of this assignment.
#
# ### Intersection as States
# Instead of defining each square as a state, use only intersections as states. Now the storage requirement is reduced, but the path length between two intersections can be different. If we use total path length measured as the number of squares as path cost, how can we make sure that BFS and iterative deepening search is optimal? Change the code to do so.

# %%
# Your code/answer goes here

# %% [markdown]
# ### Weighted A* search
# Modify your A* search to add weights (see text book) and explore how different weights influence the result.

# %%
# Your code/answer goes here

# %% [markdown]
# ### Unknown Maze
# What happens if the agent does not know the layout of the maze in advance? This means that the agent faces an unknown environment, where it does not know the transition function. How does the environment look then (PEAS description)? How would you implement a rational agent to solve the maze? What if the agent still has a GPS device to tell the distance to the goal?

# %%
# Your code/answer goes here
